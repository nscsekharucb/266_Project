# %%
from __future__ import print_function

from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.utils import to_categorical

import pandas as pd
import numpy as np
import os

import common
from importlib import reload
# %matplotlib inline

# %%
#
# Parameters
#
split = 6000
max_features = 4000
maxlen = 80
batch_size = 32
embedding_dims = 100
filters = 250
kernel_size = 3
hidden_dims = 250
epochs = 10

# %%
#
# Load the dataset
#
df = pd.read_csv('../dataset/redis_dataset.csv')
train_sentences = df['sentences'][:split]
train_categories = df['readability'][:split]

test_sentences = df['sentences'][split:]
test_categories = df['readability'][split:]
# print(train_sentences)

# %%
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(train_sentences)
train_sequences = tokenizer.texts_to_sequences(train_sentences)
test_sequences = tokenizer.texts_to_sequences(test_sentences)

dictionary = tokenizer.word_index

# %%
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(train_sequences, maxlen=maxlen)
x_test = sequence.pad_sequences(test_sequences, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (8000, 400)
# x_test shape: (1849, 400)

# %%
model = Sequential()
model.add(Dense(hidden_dims, input_shape=(maxlen,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 250)               100250
# _________________________________________________________________
# activation_15 (Activation)   (None, 250)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 502
# _________________________________________________________________
# activation_16 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 100,752
# Trainable params: 100,752
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(x_train, to_categorical(train_categories),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1, 
                    validation_data=(x_test, to_categorical(test_categories)))
# Out:
# Train on 8000 samples, validate on 1849 samples
# Epoch 1/2
# 8000/8000 [==============================] - 1s 90us/step - loss: 4.5524 - acc: 0.7158 - val_loss: 3.9933 - val_acc: 0.7463
# Epoch 2/2
# 8000/8000 [==============================] - 1s 85us/step - loss: 4.7389 - acc: 0.7000 - val_loss: 3.9944 - val_acc: 0.7469

# %%
# Evaluate the accuracy of our trained model
score = model.evaluate(x_test, to_categorical(test_categories),
                       batch_size=batch_size, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 1849/1849 [==============================] - 0s 33us/step
# Test score: 3.9944542639316127
# Test accuracy: 0.7463493779132404

# %%
# Here's how to generate a prediction on individual examples

for i in range(100):
    prediction = model.predict(np.array([x_test[i]]))
    predicted_label = np.argmax(prediction)
#     print(train_sequences.iloc[i][:50], "...")
#     print(test_sentences.iloc[i])
    print('Actual label: ', test_categories.iloc[i])
    print("Predicted label: ", predicted_label)
    print("")
# Out:
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
#
# Actual label:  1
# Predicted label:  1
#
# Actual label:  0
# Predicted label:  1
